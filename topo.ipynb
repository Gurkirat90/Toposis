# %%
! pip install topsis-gurkirat-102303256

# %%
import pandas as pd
import subprocess as sb

input_file = "topsis_dataset.csv"
weights = "0.2,0.15,0.15,0.2,0.15,0.15"
impacts = "-,+,+,+,-,+"
output_file = "result.csv"

print(f"Running TOPSIS on {input_file}...")
# !topsis {input_file} {weights} {impacts} {output_file}


try:
    results = pd.read_csv(output_file)
    print("\n Execution Successful! Here are your rankings:")
    display(results.sort_values(by="Rank"))
except:
    print("\n Output file not found. Check if 'data.xlsx' exists in the sidebar.")
# Out:
# Running TOPSIS on topsis_dataset.csv...
#
# --- TOPSIS RESULTS (Score & Rank) ---
#  Topsis Score  Rank
#      0.430121     5
#      0.628407     1
#      0.387453     6
#      0.517720     2
#      0.491573     4
#      0.496643     3
# -------------------------------------
#
# Success: Results saved to result.csv
#
# ✅ Execution Successful! Here are your rankings:
#   Alternative  Cost  Quality  DeliveryTime  Durability  Service  \
# 1          A2   200        6             7           7        7
# 3          A4   275        7             6           8        8
# 5          A6   260        8             5           8        9
# 4          A5   225        9             3           9        8
# 0          A1   250        7             5           8        8
# 2          A3   300        8             4           9        9
#
#    EnergyEfficiency  Topsis Score  Rank
# 1                 7      0.628407     1
# 3                 7      0.517720     2
# ...
